# %%
# !pip install spotipy
# Out:
# ...
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/0b/34/a01250ac1fc9bf9161e07956d2d580413106ce02d5591470130a25c599e3/redis-5.0.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/250.3 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.3 kB 660.6 kB/s eta 0:00:01
#    -------------- ------------------------- 92.2/250.3 kB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 122.9/250.3 kB 1.0 MB/s eta 0:00:01
#    ------------------------ ------------- 163.8/250.3 kB 984.6 kB/s eta 0:00:01
#    ------------------------------- ------ 204.8/250.3 kB 892.5 kB/s eta 0:00:01
#    -------------------------------------  245.8/250.3 kB 942.1 kB/s eta 0:00:01
#    -------------------------------------- 250.3/250.3 kB 854.2 kB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="d4388cd184114c39bf0fc9a2fe97315b",client_secret="c8df1c5973dd496a9f0e5c77a605c931")

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Adding Top Songs Global 
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"

# %%
playlists = sp.user_playlists('spotify')

# %%
playlist_URI=playlist_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_tracks(playlist_URI)   # Playlist_tracks is a function available in spotipy

# %%
data['items']
# Out:
# [{'added_at': '2023-11-17T08:59:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#       'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#       'id': '45dkTj5sMRSjrmBSBeiHym',
#       'name': 'Tate McRae',
#       'type': 'artist',
#       'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
data['items'][0]['track']['album']['id'] #Album INFO
# Out:
# '3UOV8XvCwMKaATRNXrYCjN'

# %%
data['items'][0]['track']['album']['name']#album 1st song name
# Out:
# 'greedy'

# %%
data['items'][0]['track']['album']['release_date'] #realsed data
# Out:
# '2023-09-15'

# %%
data['items'][0]['track']['album']['total_tracks'] #total tracks
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify'] #external any URL
# Out:
# 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'

# %%
#creating list and manging columns 
album_list=[]
for row in data['items']:
    album_id= row['track']['album']['id']
    album_name= row['track']['album']['name']
    album_release_date= row['track']['album']['release_date']
    album_total_tracks= row['track']['album']['total_tracks']
    album_url= row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                    'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'name': 'greedy',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '66k6EGkPtYoN44anGIsEPW',
#   'name': 'Si No Estás',
#   'release_date': '2022-09-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/66k6EGkPtYoN44anGIsEPW'},
#  {'album_id': '5pSk3c3wVwnb2arb6ohCPU',
#   'name': 'GOLDEN',
#   'release_date': '2023-11-03',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5pSk3c3wVwnb2arb6ohCPU'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '2Cn1d2KgbkAqbZCJ1RzdkA',
#   'name': 'The Land Is Inhospitable and So Are We',
#   'release_date': '2023-09-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/2Cn1d2KgbkAqbZCJ1RzdkA'},
# ...

# %%
data['items'] #artist info
# Out:
# [{'added_at': '2023-11-17T08:59:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#       'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#       'id': '45dkTj5sMRSjrmBSBeiHym',
#       'name': 'Tate McRae',
#       'type': 'artist',
#       'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#   'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#   'id': '6HaGTQPmzraVmaVxvz6EUc',
#   'name': 'Jung Kook',
#   'type': 'artist',
#   'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}]

# %%
artist_list=[] #All Artist List
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],
                            'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '0jbo7KFNMiIkfBR6ih0yhm',
#   'artist_name': 'iñigo quintero',
#   'external_url': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm'},
#  {'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'artist_name': 'Jung Kook',
#   'external_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '2uYWxilOVlUdk4oV9DvwqK',
#   'artist_name': 'Mitski',
#   'external_url': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
# ...

# %%
song_list=[] #Song Info,All list
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms'] 
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                   'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                   'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '3rUGC1vUpkDG9CZFHMur1t',
#   'song_name': 'greedy',
#   'duration_ms': 131872,
#   'url': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t',
#   'popularity': 100,
#   'song_added': '2023-11-17T08:59:54Z',
#   'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '2HafqoJbgXdtjwCOvNEF14',
#   'song_name': 'Si No Estás',
#   'duration_ms': 184061,
#   'url': 'https://open.spotify.com/track/2HafqoJbgXdtjwCOvNEF14',
#   'popularity': 99,
#   'song_added': '2023-11-17T08:59:54Z',
#   'album_id': '66k6EGkPtYoN44anGIsEPW',
#   'artist_id': '0jbo7KFNMiIkfBR6ih0yhm'},
#  {'song_id': '2KslE17cAJNHTsI2MI0jb2',
#   'song_name': 'Standing Next to You',
#   'duration_ms': 206019,
#   'url': 'https://open.spotify.com/track/2KslE17cAJNHTsI2MI0jb2',
#   'popularity': 97,
#   'song_added': '2023-11-17T08:59:54Z',
#   'album_id': '5pSk3c3wVwnb2arb6ohCPU',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
# ...

# %%
#Coverting Into Data Frame 
import pandas as pd
album_df= pd.DataFrame.from_dict(album_list) ### album_df
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.head()
# Out:
#                  album_id                                    name  \
# 0  3UOV8XvCwMKaATRNXrYCjN                                  greedy
# 1  66k6EGkPtYoN44anGIsEPW                             Si No Estás
# 2  5pSk3c3wVwnb2arb6ohCPU                                  GOLDEN
# 3  1NAmidJlEaVgA3MpcPFYGq                                   Lover
# 4  2Cn1d2KgbkAqbZCJ1RzdkA  The Land Is Inhospitable and So Are We
#
#   release_date  total_tracks  \
# 0   2023-09-15             1
# 1   2022-09-23             1
# 2   2023-11-03            11
# 3   2019-08-23            18
# 4   2023-09-15            11
#
#                                                  url
# 0  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 1  https://open.spotify.com/album/66k6EGkPtYoN44a...
# 2  https://open.spotify.com/album/5pSk3c3wVwnb2ar...
# 3  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 4  https://open.spotify.com/album/2Cn1d2KgbkAqbZC...

# %%
artist_df= pd.DataFrame.from_dict(artist_list) ### artist_df all artist
artist_df = artist_df.drop_duplicates(subset=['artist_id'])
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  45dkTj5sMRSjrmBSBeiHym      Tate McRae
# 1  0jbo7KFNMiIkfBR6ih0yhm  iñigo quintero
# 2  6HaGTQPmzraVmaVxvz6EUc       Jung Kook
# 3  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 4  2uYWxilOVlUdk4oV9DvwqK          Mitski
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 1  https://api.spotify.com/v1/artists/0jbo7KFNMiI...
# 2  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 3  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 4  https://api.spotify.com/v1/artists/2uYWxilOVlU...

# %%
song_df= pd.DataFrame.from_dict(song_list) # song_df
song_df.head(10) # there are no duplicates so no need drop duplicates
# Out:
#                   song_id                                          song_name  \
# 0  3rUGC1vUpkDG9CZFHMur1t                                             greedy
# 1  2HafqoJbgXdtjwCOvNEF14                                        Si No Estás
# 2  2KslE17cAJNHTsI2MI0jb2                               Standing Next to You
# 3  1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 4  3vkCueOmm7xQDoJ17W1Pm3                              My Love Mine All Mine
# 5  4OMJGnvZfDvsePyCwRGO7X                                            Houdini
# 6  2HRgqmZQC0MC7GeNuDIXHN                Seven (feat. Latto) (Explicit Ver.)
# 7  7iQXYTyuG13aoeHxGG28Nh                                        PERRO NEGRO
# 8  56y1jOTK0XSvJzVv9vHQBK                                 Paint The Town Red
# 9  1Iq8oo9XkmmvCQiGOfORiz  Is It Over Now? (Taylor's Version) (From The V...
#
#    duration_ms                                                url  popularity  \
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      44 non-null     object
#  1   name          44 non-null     object
#  2   release_date  44 non-null     datetime64[ns]
#  3   total_tracks  44 non-null     int64
#  4   url           44 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added']) #Song added
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
album_df.head(6) #album list
# Out:
#                  album_id                                    name  \
# 0  3UOV8XvCwMKaATRNXrYCjN                                  greedy
# 1  66k6EGkPtYoN44anGIsEPW                             Si No Estás
# 2  5pSk3c3wVwnb2arb6ohCPU                                  GOLDEN
# 3  1NAmidJlEaVgA3MpcPFYGq                                   Lover
# 4  2Cn1d2KgbkAqbZCJ1RzdkA  The Land Is Inhospitable and So Are We
# 5  5pTaRVLwZOFObIbRBubmeb                                 Houdini
#
#   release_date  total_tracks  \
# 0   2023-09-15             1
# 1   2022-09-23             1
# 2   2023-11-03            11
# 3   2019-08-23            18
# 4   2023-09-15            11
# 5   2023-11-09             1
#
#                                                  url
# 0  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 1  https://open.spotify.com/album/66k6EGkPtYoN44a...
# 2  https://open.spotify.com/album/5pSk3c3wVwnb2ar...
# 3  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# ...

# %%
artist_df.head() #artist list
# Out:
#                 artist_id     artist_name  \
# 0  45dkTj5sMRSjrmBSBeiHym      Tate McRae
# 1  0jbo7KFNMiIkfBR6ih0yhm  iñigo quintero
# 2  6HaGTQPmzraVmaVxvz6EUc       Jung Kook
# 3  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 4  2uYWxilOVlUdk4oV9DvwqK          Mitski
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 1  https://api.spotify.com/v1/artists/0jbo7KFNMiI...
# 2  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 3  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 4  https://api.spotify.com/v1/artists/2uYWxilOVlU...

# %%
song_df.head(10) #song list
# Out:
#                   song_id                                          song_name  \
# 0  3rUGC1vUpkDG9CZFHMur1t                                             greedy
# 1  2HafqoJbgXdtjwCOvNEF14                                        Si No Estás
# 2  2KslE17cAJNHTsI2MI0jb2                               Standing Next to You
# 3  1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 4  3vkCueOmm7xQDoJ17W1Pm3                              My Love Mine All Mine
# 5  4OMJGnvZfDvsePyCwRGO7X                                            Houdini
# 6  2HRgqmZQC0MC7GeNuDIXHN                Seven (feat. Latto) (Explicit Ver.)
# 7  7iQXYTyuG13aoeHxGG28Nh                                        PERRO NEGRO
# 8  56y1jOTK0XSvJzVv9vHQBK                                 Paint The Town Red
# 9  1Iq8oo9XkmmvCQiGOfORiz  Is It Over Now? (Taylor's Version) (From The V...
#
#    duration_ms                                                url  popularity  \
# ...

# %%
song_df.head(51)#we have total 50 Top Global songs in playlist
# Out:
#                    song_id                                          song_name  \
# 0   3rUGC1vUpkDG9CZFHMur1t                                             greedy
# 1   2HafqoJbgXdtjwCOvNEF14                                        Si No Estás
# 2   2KslE17cAJNHTsI2MI0jb2                               Standing Next to You
# 3   1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 4   3vkCueOmm7xQDoJ17W1Pm3                              My Love Mine All Mine
# 5   4OMJGnvZfDvsePyCwRGO7X                                            Houdini
# 6   2HRgqmZQC0MC7GeNuDIXHN                Seven (feat. Latto) (Explicit Ver.)
# 7   7iQXYTyuG13aoeHxGG28Nh                                        PERRO NEGRO
# 8   56y1jOTK0XSvJzVv9vHQBK                                 Paint The Town Red
# 9   1Iq8oo9XkmmvCQiGOfORiz  Is It Over Now? (Taylor's Version) (From The V...
# 10  4MjDJD8cW7iVeWInc2Bdyj                                             MONACO
# ...

# %%
pip install boto3
# Out:
# ...
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/f2/23/c5545cb57abfc3a9782287f2845a26286f6f9f7bcec36f13569567f950fe/boto3-1.29.5-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for botocore<1.33.0,>=1.32.5 from https://files.pythonhosted.org/packages/02/55/7070f28d963cf8843e1335c8c3de0a37dd6382b53e83315ddaab1f645f5e/botocore-1.32.5-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for s3transfer<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/5a/4b/fec9ce18f8874a96c5061422625ba86c3ee1e6587ccd92ff9f5bf7bd91b2/s3transfer-0.7.0-py3-none-any.whl.metadata
#   Using cached s3transfer-0.7.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#    ---------------------------------------- 0.0/135.8 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/135.8 kB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 112.6/135.8 kB 1.3 MB/s eta 0:00:01
# ...

# %%
import json
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import boto3
from datetime import datetime

def lambda_handler(event, context):
    
    client_id=os.environ.get('client_id')
    client_secret=os.environ.get('client_secret')
    
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
    sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    playlists = sp.user_playlists('spotify')
    
    playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
    playlist_URI=playlist_link.split("/")[-1].split("?")[0]
    
    spotify_data = sp.playlist_tracks(playlist_URI)
    
    client = boto3.client('s3')
    
    filename = "spotify_raw_" + str(datetime.now()) + ".json"
    
    client.put_object(
        Bucket = "spotify-etl-project-sachink",
        Key = "raw_data/to_processed/" + filename,
        Body = json.dumps(spotify_data)
        )
